# %% [markdown]
# <a href="https://colab.research.google.com/github/qwertyz15/Diabetes-Prediction/blob/main/Diabetes_Prediction_2011_2017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import Necessary libraries
import os 

# Set Directory path for Dataset
os.chdir("/content/drive/My Drive/")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing dataset
df1 = pd.read_excel('Diabetes-2011.xlsx')

# %%
#importing dataset
df2 = pd.read_excel('Diabetes-2017-18.xlsx')

# %%
df1
# Out:
#       HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB    SHBM  Diabetes
# 0         1      2      3      2  ...    125.0     76.0  2119.0         0
# 1         1      2      3      1  ...    127.0     72.0  9999.0         0
# 2         1      2      2      1  ...    122.0     82.0  2068.0         1
# 3         1      2      1      1  ...    159.0    103.0  9999.0         0
# 4         1      2      1      2  ...    129.0     65.0  1716.0         0
# ...     ...    ...    ...    ...  ...      ...      ...     ...       ...
# 7560      7      2      1      2  ...     93.0     56.0     NaN         1
# 7561      7      2      2      1  ...     97.0     68.0  2083.0         1
# 7562      7      2      2      2  ...    116.0     73.0  2205.0         1
# 7563      7      2      4      1  ...    115.0     80.0  2224.0         2
# 7564      7      2      4      2  ...    140.0    106.0     NaN         1
#
# [7565 rows x 14 columns]

# %%
df1.rename(columns={"Diabetes": "Deabetic", "SHBM" : "SBBM", "SH239" : "SB308"}, inplace = True)

# %%
df2
# Out:
#        HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB  Deabetic  SBBM
# 0          1      2      1      1  ...      111       58         1  2055
# 1          1      2      1      2  ...      101       67         1  2481
# 2          1      2      1      2  ...      100       66         1  1744
# 3          1      2      1      1  ...      105       71         1  2108
# 4          1      2      1      2  ...      144       94         1  2455
# ...      ...    ...    ...    ...  ...      ...      ...       ...   ...
# 12294      8      1      5      2  ...      129       96         1  2682
# 12295      8      1      5      2  ...      110       79         1  2389
# 12296      8      1      5      1  ...      114       69         1  2154
# 12297      8      1      5      2  ...      130       79         0  2761
# 12298      8      1      5      2  ...      142       71         1  1597
#
# [12299 rows x 14 columns]

# %%
frames = [df1, df2]
df = pd.concat(frames)
df
# Out:
#        HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB    SBBM  Deabetic
# 0          1      2      3      2  ...    125.0     76.0  2119.0         0
# 1          1      2      3      1  ...    127.0     72.0  9999.0         0
# 2          1      2      2      1  ...    122.0     82.0  2068.0         1
# 3          1      2      1      1  ...    159.0    103.0  9999.0         0
# 4          1      2      1      2  ...    129.0     65.0  1716.0         0
# ...      ...    ...    ...    ...  ...      ...      ...     ...       ...
# 12294      8      1      5      2  ...    129.0     96.0  2682.0         1
# 12295      8      1      5      2  ...    110.0     79.0  2389.0         1
# 12296      8      1      5      1  ...    114.0     69.0  2154.0         1
# 12297      8      1      5      2  ...    130.0     79.0  2761.0         0
# 12298      8      1      5      2  ...    142.0     71.0  1597.0         1
#
# [19864 rows x 14 columns]

# %%
df1.describe()
# Out:
#              HV024        HV025  ...         SBBM     Deabetic
# count  7565.000000  7565.000000  ...  5465.000000  7565.000000
# mean      3.976338     1.670985  ...  2393.735773     0.730205
# std       1.897310     0.469887  ...  1620.589268     0.633578
# min       1.000000     1.000000  ...  1289.000000     0.000000
# 25%       2.000000     1.000000  ...  1812.000000     0.000000
# 50%       4.000000     2.000000  ...  2028.000000     1.000000
# 75%       6.000000     2.000000  ...  2321.000000     1.000000
# max       7.000000     2.000000  ...  9999.000000     2.000000
#
# [8 rows x 14 columns]

# %%
df2.describe()
# Out:
#               HV024         HV025  ...      Deabetic          SBBM
# count  12299.000000  12299.000000  ...  12299.000000  12299.000000
# mean       4.519067      1.642816  ...      0.510204   2328.192617
# std        2.240941      0.479189  ...      0.649848    924.122039
# min        1.000000      1.000000  ...      0.000000   1219.000000
# 25%        3.000000      1.000000  ...      0.000000   1941.000000
# 50%        4.000000      2.000000  ...      0.000000   2199.000000
# 75%        6.000000      2.000000  ...      1.000000   2503.000000
# max        8.000000      2.000000  ...      2.000000   9999.000000
#
# [8 rows x 14 columns]

# %%
df.head()
# Out:
#    HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB    SBBM  Deabetic
# 0      1      2      3      2  ...    125.0     76.0  2119.0         0
# 1      1      2      3      1  ...    127.0     72.0  9999.0         0
# 2      1      2      2      1  ...    122.0     82.0  2068.0         1
# 3      1      2      1      1  ...    159.0    103.0  9999.0         0
# 4      1      2      1      2  ...    129.0     65.0  1716.0         0
#
# [5 rows x 14 columns]

# %% [markdown]
# #**Exploratory Data Analysis**

# %%
df.describe(include='all')
# Out:
#               HV024         HV025  ...          SBBM      Deabetic
# count  19864.000000  19864.000000  ...  17764.000000  19864.000000
# mean       4.312374      1.653544  ...   2348.356620      0.593989
# std        2.132956      0.475853  ...   1183.233109      0.652489
# min        1.000000      1.000000  ...   1219.000000      0.000000
# 25%        3.000000      1.000000  ...   1896.000000      0.000000
# 50%        4.000000      2.000000  ...   2142.000000      1.000000
# 75%        6.000000      2.000000  ...   2456.000000      1.000000
# max        8.000000      2.000000  ...   9999.000000      2.000000
#
# [8 rows x 14 columns]

# %%
min_thresold, max_thresold = df.SBBM.quantile([0.005, 0.95])
min_thresold, max_thresold
# Out:
# (1434.815, 3036.8499999999985)

# %%
df = df[(df.SBBM < max_thresold) & (df.SBBM > min_thresold)]
df.shape
# Out:
# (16786, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16786 entries, 0 to 12298
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   HV024     16786 non-null  int64
#  1   HV025     16786 non-null  int64
#  2   HV270     16786 non-null  int64
#  3   HV104     16786 non-null  int64
#  4   HV105     16786 non-null  int64
#  5   HV106     16786 non-null  int64
#  6   SB308     16786 non-null  int64
#  7   SB311A    16778 non-null  float64
#  8   SB311B    16778 non-null  float64
#  9   SB311C    16778 non-null  float64
#  10  SB333AA   16783 non-null  float64
#  11  SB333AB   16783 non-null  float64
#  12  SBBM      16786 non-null  float64
#  13  Deabetic  16786 non-null  int64
# dtypes: float64(6), int64(8)
# memory usage: 1.9 MB

# %%
df.shape
# Out:
# (16786, 14)

# %% [markdown]
# ##**Missing Data**

# %%
df.isnull()
# Out:
#        HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB   SBBM  Deabetic
# 0      False  False  False  False  ...    False    False  False     False
# 2      False  False  False  False  ...    False    False  False     False
# 4      False  False  False  False  ...    False    False  False     False
# 5      False  False  False  False  ...    False    False  False     False
# 8      False  False  False  False  ...    False    False  False     False
# ...      ...    ...    ...    ...  ...      ...      ...    ...       ...
# 12294  False  False  False  False  ...    False    False  False     False
# 12295  False  False  False  False  ...    False    False  False     False
# 12296  False  False  False  False  ...    False    False  False     False
# 12297  False  False  False  False  ...    False    False  False     False
# 12298  False  False  False  False  ...    False    False  False     False
#
# [16786 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# HV024       0
# HV025       0
# HV270       0
# HV104       0
# HV105       0
# HV106       0
# SB308       0
# SB311A      8
# SB311B      8
# SB311C      8
# SB333AA     3
# SB333AB     3
# SBBM        0
# Deabetic    0
# dtype: int64

# %%
df2 = df.fillna(df.mean())
df2
# Out:
#        HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB    SBBM  Deabetic
# 0          1      2      3      2  ...    125.0     76.0  2119.0         0
# 2          1      2      2      1  ...    122.0     82.0  2068.0         1
# 4          1      2      1      2  ...    129.0     65.0  1716.0         0
# 5          1      2      4      1  ...    130.0     88.0  1858.0         0
# 8          1      2      4      2  ...    190.0     96.0  1539.0         1
# ...      ...    ...    ...    ...  ...      ...      ...     ...       ...
# 12294      8      1      5      2  ...    129.0     96.0  2682.0         1
# 12295      8      1      5      2  ...    110.0     79.0  2389.0         1
# 12296      8      1      5      1  ...    114.0     69.0  2154.0         1
# 12297      8      1      5      2  ...    130.0     79.0  2761.0         0
# 12298      8      1      5      2  ...    142.0     71.0  1597.0         1
#
# [16786 rows x 14 columns]

# %%
df2 = df2.reset_index()
df2 = df2.drop(columns=['index'])
df2.tail()
# Out:
#        HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB    SBBM  Deabetic
# 16781      8      1      5      2  ...    129.0     96.0  2682.0         1
# 16782      8      1      5      2  ...    110.0     79.0  2389.0         1
# 16783      8      1      5      1  ...    114.0     69.0  2154.0         1
# 16784      8      1      5      2  ...    130.0     79.0  2761.0         0
# 16785      8      1      5      2  ...    142.0     71.0  1597.0         1
#
# [5 rows x 14 columns]

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Deabetic',data= df2)

# %% [markdown]
# **There are three categories of diabetics (0,1,2). 0 means no diabetes, 1 means type 1 diabetic, 2 means type 2 diabetic. But we want to predict whether the patient has diabetes or not. We, therefore, group together all type 1 and type 2 diabetic patients in the same category.**

# %%
filt = ((df2['Deabetic'] == 1) | (df2['Deabetic'] == 2))
df3 = df2.copy()
df3.loc[filt, 'Deabetic'] = 1

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Deabetic',data= df3)

# %% [markdown]
# ###***Visualization based on SEX***

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'HV104',data= df3)

# %%
sns.set_style('whitegrid')
sns.countplot(x='Deabetic', hue='HV104', data=df3, palette='RdBu_r')

# %% [markdown]
# ###***Visualization of Eating Anything***

# %%
df3['SB311A'].value_counts()
# Out:
# 0.000000    11671
# 1.000000     5101
# 0.307248        8
# 9.000000        6
# Name: SB311A, dtype: int64

# %%
filt = df3['SB311A'] == 9.0
df3.loc[filt, 'SB311A'] = np.nan
df4 = df3.dropna()
df4 = df4.reset_index()
df4 = df4.drop(columns = {'index'})
df4.tail()
# Out:
#        HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB    SBBM  Deabetic
# 16775      8      1      5      2  ...    129.0     96.0  2682.0         1
# 16776      8      1      5      2  ...    110.0     79.0  2389.0         1
# 16777      8      1      5      1  ...    114.0     69.0  2154.0         1
# 16778      8      1      5      2  ...    130.0     79.0  2761.0         0
# 16779      8      1      5      2  ...    142.0     71.0  1597.0         1
#
# [5 rows x 14 columns]

# %%
sns.set_style('whitegrid')
sns.countplot(x='Deabetic', hue='SB311A', data=df4, palette='RdBu_r')

# %% [markdown]
# ###***Visualization based on Caffeinated drink***

# %%
df4['SB311B'].value_counts()
# Out:
# 0.000000    15647
# 1.000000     1118
# 0.073608        8
# 9.000000        7
# Name: SB311B, dtype: int64

# %%
filt = df4['SB311B'] == 9.0
df4.loc[filt, 'SB311B'] = np.nan
df5 = df4.dropna()
df5 = df5.reset_index()
df5 = df5.drop(columns = {'index'})
df5.tail()
# Out:
#        HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB    SBBM  Deabetic
# 16768      8      1      5      2  ...    129.0     96.0  2682.0         1
# 16769      8      1      5      2  ...    110.0     79.0  2389.0         1
# 16770      8      1      5      1  ...    114.0     69.0  2154.0         1
# 16771      8      1      5      2  ...    130.0     79.0  2761.0         0
# 16772      8      1      5      2  ...    142.0     71.0  1597.0         1
#
# [5 rows x 14 columns]

# %%
sns.set_style('whitegrid')
sns.countplot(x='Deabetic', hue='SB311B', data=df5, palette='RdBu_r')

# %% [markdown]
# ###***Visualization based on Smoker***

# %%
df5['SB311C'].value_counts()
# Out:
# 0.000000    14205
# 1.000000     2558
# 0.158899        8
# 9.000000        2
# Name: SB311C, dtype: int64

# %%
filt = df5['SB311C'] == 9.0
df5.loc[filt, 'SB311C'] = np.nan
df6 = df5.dropna()
df6 = df6.reset_index()
df6 = df6.drop(columns = {'index'})
df6.tail()
# Out:
#        HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB    SBBM  Deabetic
# 16766      8      1      5      2  ...    129.0     96.0  2682.0         1
# 16767      8      1      5      2  ...    110.0     79.0  2389.0         1
# 16768      8      1      5      1  ...    114.0     69.0  2154.0         1
# 16769      8      1      5      2  ...    130.0     79.0  2761.0         0
# 16770      8      1      5      2  ...    142.0     71.0  1597.0         1
#
# [5 rows x 14 columns]

# %%
sns.set_style('whitegrid')
sns.countplot(x='Deabetic', hue='SB311C', data=df6, palette='RdBu_r')

# %% [markdown]
# ###***Visualization based on age***

# %%
sns.distplot(df6['HV105'],kde=False,color='darkred',bins=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
c1 = (df6['HV105'] < 0) | (df6['HV105'] <= 20)
sb1 = df6[c1].mean()
c2 = (df6['HV105'] < 20) | (df6['HV105'] <= 30)
sb2 = df6[c1].mean()
c3 = (df6['HV105'] < 30) | (df6['HV105'] <= 40)
sb3 = df6[c1].mean()
c4 = (df6['HV105'] < 40) | (df6['HV105'] <= 50)
sb4 = df6[c1].mean()
c5 = (df6['HV105'] < 50) | (df6['HV105'] <= 60)
sb5 = df6[c1].mean()
c6 = (df6['HV105'] < 60) | (df6['HV105'] <= 70)
sb6 = df6[c1].mean()
c7 = (df6['HV105'] < 70) | (df6['HV105'] <= 80)
sb7 = df6[c1].mean()
c8 = (df6['HV105'] < 80) | (df6['HV105'] <= 90)
sb8 = df6[c1].mean()
c9 = (df6['HV105'] < 90)
sb9 = df6[c1].mean()

# %% [markdown]
# #**Feature Selection**

# %% [markdown]
# ###***Correlation Heatmap***

# %%
df6.corr()
# Out:
#              HV024     HV025     HV270  ...   SB333AB      SBBM  Deabetic
# HV024     1.000000  0.054648 -0.089644  ...  0.001820 -0.042599 -0.109944
# HV025     0.054648  1.000000 -0.407111  ... -0.035585 -0.164645 -0.051443
# HV270    -0.089644 -0.407111  1.000000  ...  0.066724  0.314233  0.125498
# HV104     0.007693  0.017111 -0.026313  ...  0.029503  0.124480 -0.032182
# HV105    -0.065545  0.067978 -0.011582  ...  0.060529 -0.139461  0.141415
# HV106    -0.033417 -0.169825  0.391931  ...  0.018477  0.264121 -0.018713
# SB308     0.005044 -0.130507  0.106497  ...  0.017065  0.077672  0.029749
# SB311A   -0.004924  0.030058 -0.014451  ... -0.004770  0.033363 -0.010096
# SB311B   -0.011237 -0.048176  0.067555  ...  0.010290  0.040460  0.028353
# SB311C    0.015418  0.051292 -0.096765  ... -0.008943 -0.044650 -0.010971
# SB333AA   0.005223 -0.025685  0.059139  ...  0.816541  0.132485 -0.011699
# SB333AB   0.001820 -0.035585  0.066724  ...  1.000000  0.162273 -0.030433
# SBBM     -0.042599 -0.164645  0.314233  ...  0.162273  1.000000  0.047763
# Deabetic -0.109944 -0.051443  0.125498  ... -0.030433  0.047763  1.000000
#
# [14 rows x 14 columns]

# %%
#get correlations of each features in dataset
corrmat = df6.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,10))
#plot heat map
g=sns.heatmap(df6[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# ###***Univariate Selection***

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X = df6.copy()  #independent columns
y = X.pop('Deabetic')    #target column i.e price range

# %%
X.head()
# Out:
#    HV024  HV025  HV270  HV104  HV105  ...  SB311B  SB311C  SB333AA  SB333AB    SBBM
# 0      1      2      3      2     58  ...     0.0     0.0    125.0     76.0  2119.0
# 1      1      2      2      1     36  ...     0.0     0.0    122.0     82.0  2068.0
# 2      1      2      1      2     55  ...     0.0     0.0    129.0     65.0  1716.0
# 3      1      2      4      1     55  ...     0.0     0.0    130.0     88.0  1858.0
# 4      1      2      4      2     70  ...     0.0     0.0    190.0     96.0  1539.0
#
# [5 rows x 13 columns]

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: Deabetic, dtype: int64

# %%
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

# %%
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns

# %%
featureScores
# Out:
#       Specs        Score
# 0     HV024   217.117810
# 1     HV025     6.029160
# 2     HV270   175.403425
# 3     HV104     2.928430
# 4     HV105  2162.198125
# 5     HV106     5.211306
# 6     SB308   294.068952
# 7    SB311A     1.189070
# 8    SB311B    12.576903
# 9    SB311C     1.709723
# 10  SB333AA    12.506067
# 11  SB333AB    73.390757
# 12     SBBM  2153.991837

# %%
print(featureScores.nlargest(13,'Score'))  #print 30 best features
# Out:
#       Specs        Score
# 4     HV105  2162.198125
# 12     SBBM  2153.991837
# 6     SB308   294.068952
# 0     HV024   217.117810
# 2     HV270   175.403425
# 11  SB333AB    73.390757
# 8    SB311B    12.576903
# 10  SB333AA    12.506067
# 1     HV025     6.029160
# 5     HV106     5.211306
# 3     HV104     2.928430
# 9    SB311C     1.709723
# 7    SB311A     1.189070

# %% [markdown]
# ###***Feature Importance***

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
# Out:
# [0.09356484 0.01747157 0.062385   0.01868766 0.15944708 0.06168612
#  0.08396286 0.02438852 0.00971555 0.01716952 0.14995406 0.1468826
#  0.15468463]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(13).plot(kind='barh')
plt.show()

# %% [markdown]
# #**Train Test Split**

# %%
from sklearn.model_selection import train_test_split
feature_columns = ['SBBM', 'HV105', 'SB333AA', 'SB333AB', 'HV024', 'SB308', 'HV106', 'HV270']
predicted_class = ['Deabetic']

# %%
data = pd.DataFrame(columns = feature_columns, data = df6)
data['Deabetic'] = df6['Deabetic']
data
# Out:
#          SBBM  HV105  SB333AA  SB333AB  HV024  SB308  HV106  HV270  Deabetic
# 0      2119.0     58    125.0     76.0      1      0      0      3         0
# 1      2068.0     36    122.0     82.0      1     52      1      2         1
# 2      1716.0     55    129.0     65.0      1      0      0      1         0
# 3      1858.0     55    130.0     88.0      1     11      3      4         0
# 4      1539.0     70    190.0     96.0      1      0      0      4         1
# ...       ...    ...      ...      ...    ...    ...    ...    ...       ...
# 16766  2682.0     33    129.0     96.0      8      0      2      5         1
# 16767  2389.0     20    110.0     79.0      8     31      2      5         1
# 16768  2154.0     62    114.0     69.0      8     31      2      5         1
# 16769  2761.0     51    130.0     79.0      8      0      1      5         0
# 16770  1597.0     80    142.0     71.0      8      0      0      5         1
#
# [16771 rows x 9 columns]

# %%
random = 32

# %%
X = data[feature_columns].values
y = data[predicted_class].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state= random)

# %% [markdown]
# #**Feature Scaling**

# %%
#Feature scaling

from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %% [markdown]
# #**Classifiers**

# %% [markdown]
# ###***Logistic Regression***

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
LGclassifier = LogisticRegression(random_state= random)
LGclassifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=32, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predict_train_data = LGclassifier.predict(X_test)

from sklearn import metrics

print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.603

# %% [markdown]
# ###***Naive Bayes***

# %%
from sklearn.naive_bayes import GaussianNB
NBclassifier = GaussianNB()
NBclassifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py:206: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
predict_train_data = NBclassifier.predict(X_test)

from sklearn import metrics

print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.528

# %% [markdown]
# ###***Decision Tree***

# %%
# Fitting Decision tree classifier to the Training set
from sklearn.tree import DecisionTreeClassifier
DSclassifier = DecisionTreeClassifier(criterion='entropy', random_state=0)
DSclassifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
predict_train_data = DSclassifier.predict(X_test)

from sklearn import metrics

print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.536

# %% [markdown]
# ###***Random Forest***

# %%
## Apply Algorithm

from sklearn.ensemble import RandomForestClassifier
random_forest_model = RandomForestClassifier(random_state= random)

random_forest_model.fit(X_train, y_train.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=32, verbose=0,
#                        warm_start=False)

# %%
predict_train_data = random_forest_model.predict(X_test)

from sklearn import metrics

print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.596

# %% [markdown]
# ###***SVM***

# %%
# Fitting SVM classifier to the Training set
from sklearn.svm import SVC
SVMclassifier = SVC(kernel='linear', random_state= random)
SVMclassifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=32, shrinking=True, tol=0.001,
#     verbose=False)

# %%
predict_train_data = SVMclassifier.predict(X_test)

from sklearn import metrics

print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.604

# %% [markdown]
# ###***Kernel SVM***

# %% [markdown]
# **kernel = 'rbf'**

# %%
# Fitting classifier to the Training set
from sklearn.svm import SVC
KSVMclassifier = SVC(kernel='rbf', random_state=0)
KSVMclassifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
predict_train_data = KSVMclassifier.predict(X_test)

from sklearn import metrics

print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.622

# %% [markdown]
# **kernel = 'poly'**

# %%
# Fitting classifier to the Training set
from sklearn.svm import SVC
KSVMclassifier = SVC(kernel='poly', random_state=0)
KSVMclassifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
predict_train_data = KSVMclassifier.predict(X_test)

from sklearn import metrics

print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.604

# %% [markdown]
# ###***XG Boost***

# %%
## Hyper Parameter Optimization

params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
    
}

# %%
## Hyperparameter optimization using RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV
import xgboost

# %%
classifier=xgboost.XGBClassifier()

# %%
random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
from datetime import datetime
# Here we go
start_time = timer(None) # timing starts from this point for "start_time" variable
random_search.fit(X,y.ravel())
timer(start_time) # timing ends here for "start_time" variable
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   22.9s finished
#  Time taken: 0 hours 0 minutes and 25.13 seconds.

# %%
random_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5, gamma=0.3,
#               learning_rate=0.25, max_delta_step=0, max_depth=15,
#               min_child_weight=3, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
classifier=xgboost.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.4, gamma=0.0,
              learning_rate=0.25, max_delta_step=0, max_depth=4,
              min_child_weight=3, missing=None, n_estimators=100, n_jobs=1,
              nthread=None, objective='binary:logistic', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
              silent=None, subsample=1, verbosity=1)

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(classifier,X,y.ravel(),cv=10)
score
# Out:
# array([0.44517282, 0.3673226 , 0.1013715 , 0.03756708, 0.20214669,
#        0.3875969 , 0.33154442, 0.21347645, 0.29039952, 0.5503876 ])

# %%
score.mean()
# Out:
# 0.29269855856739463

# %% [markdown]
# ###***KNN***

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import cross_val_score
knn_scores = []
for k in range(1,21):
    knn_classifier = KNeighborsClassifier(n_neighbors = k)
    score=cross_val_score(knn_classifier,X,y,cv=10)
    knn_scores.append(score.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)

# %%
plt.figure(figsize=(25,15))
plt.plot([k for k in range(1, 21)], knn_scores, color = 'red')

for i in range(1,21):
    plt.text(i, knn_scores[i-1], (i, knn_scores[i-1]))
    plt.xticks([i for i in range(1, 21)])
    plt.xlabel('Number of Neighbors (K)')
    plt.ylabel('Scores')
    plt.title('K Neighbors Classifier scores for different K values')

# %%
knn_classifier = KNeighborsClassifier(n_neighbors = 20)
score=cross_val_score(knn_classifier,X,y,cv=10)
score.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# 0.5530988206848172

# %% [markdown]
# #***TabNet***

# %%
# !pip install pytorch-tabnet
# Out:
# Collecting pytorch-tabnet
#   Downloading https://files.pythonhosted.org/packages/94/e5/2a808d611a5d44e3c997c0d07362c04a56c70002208e00aec9eee3d923b5/pytorch_tabnet-3.1.1-py3-none-any.whl
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.7/dist-packages (from pytorch-tabnet) (0.22.2.post1)
# Requirement already satisfied: torch<2.0,>=1.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-tabnet) (1.8.0+cu101)
# Requirement already satisfied: tqdm<5.0,>=4.36 in /usr/local/lib/python3.7/dist-packages (from pytorch-tabnet) (4.41.1)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.7/dist-packages (from pytorch-tabnet) (1.19.5)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.7/dist-packages (from pytorch-tabnet) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (1.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch<2.0,>=1.2->pytorch-tabnet) (3.7.4.3)
# Installing collected packages: pytorch-tabnet
# Successfully installed pytorch-tabnet-3.1.1

# %%
df6
# Out:
#        HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB    SBBM  Deabetic
# 0          1      2      3      2  ...    125.0     76.0  2119.0         0
# 1          1      2      2      1  ...    122.0     82.0  2068.0         1
# 2          1      2      1      2  ...    129.0     65.0  1716.0         0
# 3          1      2      4      1  ...    130.0     88.0  1858.0         0
# 4          1      2      4      2  ...    190.0     96.0  1539.0         1
# ...      ...    ...    ...    ...  ...      ...      ...     ...       ...
# 16766      8      1      5      2  ...    129.0     96.0  2682.0         1
# 16767      8      1      5      2  ...    110.0     79.0  2389.0         1
# 16768      8      1      5      1  ...    114.0     69.0  2154.0         1
# 16769      8      1      5      2  ...    130.0     79.0  2761.0         0
# 16770      8      1      5      2  ...    142.0     71.0  1597.0         1
#
# [16771 rows x 14 columns]

# %%
X = df6.copy()  #independent columns
y = X.pop('Deabetic')    #target column i.e price range

# %%
X
# Out:
#        HV024  HV025  HV270  HV104  ...  SB311C  SB333AA  SB333AB    SBBM
# 0          1      2      3      2  ...     0.0    125.0     76.0  2119.0
# 1          1      2      2      1  ...     0.0    122.0     82.0  2068.0
# 2          1      2      1      2  ...     0.0    129.0     65.0  1716.0
# 3          1      2      4      1  ...     0.0    130.0     88.0  1858.0
# 4          1      2      4      2  ...     0.0    190.0     96.0  1539.0
# ...      ...    ...    ...    ...  ...     ...      ...      ...     ...
# 16766      8      1      5      2  ...     1.0    129.0     96.0  2682.0
# 16767      8      1      5      2  ...     0.0    110.0     79.0  2389.0
# 16768      8      1      5      1  ...     0.0    114.0     69.0  2154.0
# 16769      8      1      5      2  ...     1.0    130.0     79.0  2761.0
# 16770      8      1      5      2  ...     0.0    142.0     71.0  1597.0
#
# [16771 rows x 13 columns]

# %%
y
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 16766    1
# 16767    1
# 16768    1
# 16769    0
# 16770    1
# Name: Deabetic, Length: 16771, dtype: int64

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train, X_test
# Out:
# (array([[ 1.21522903, -1.37890684,  1.36454092, ...,  0.11515496,
#           0.72781629, -0.15888168],
#         [-1.55897124,  0.72521215, -1.44151073, ..., -0.74368299,
#          -0.56310515, -0.35358596],
#         [-1.09660453, -1.37890684,  1.36454092, ..., -0.10888972,
#          -0.18060991,  1.6822191 ],
#         ...,
#         [-0.17187111,  0.72521215, -0.03848491, ..., -0.1462305 ,
#          -0.0849861 ,  0.48822373],
#         [-0.17187111, -1.37890684, -1.44151073, ...,  0.52590355,
#          -0.0849861 ,  0.59130246],
#         [-0.17187111, -1.37890684,  1.36454092, ...,  0.67526667,
#           1.15812343, -1.18107916]]),
#  array([[-0.63423782,  0.72521215,  1.36454092, ..., -0.81836455,
#          -0.9456004 , -0.54256365],
#         [-1.55897124,  0.72521215, -1.44151073, ...,  0.37654043,
#           0.20188533, -1.40155313],
#         [-0.17187111,  0.72521215, -1.44151073, ..., -0.1462305 ,
#          -0.18060991, -1.30992758],
#         ...,
#         [ 1.21522903,  0.72521215,  0.66302801, ...,  1.64612697,
#           1.15812343,  2.00004521],
#         [-0.63423782,  0.72521215, -0.03848491, ...,  0.11515496,
#           0.05844961, -0.96919509],
#         [-1.09660453,  0.72521215,  0.66302801, ..., -1.15443158,
#          -0.84997659, -0.48816098]]))

# %%
from pytorch_tabnet.tab_model import TabNetClassifier

classifier = TabNetClassifier(verbose=0,seed=42)
classifier.fit(X_train=X_train, y_train=y_train,
               patience=5,max_epochs=100,
               eval_metric=['auc'])
# Out:
# No early stopping will be performed, last training weights will be used.

# %%
predictions = classifier.predict_proba(X_test)[:,1]
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1089,  661],
#        [ 586, 1019]])

# %%
(cm[0][0] + cm[1][1]) / (cm[0][0] + cm[0][1] + cm[1][0] + cm[1][1])
# Out:
# 0.6283159463487332

# %% [markdown]
# #***Aritificial Neural Network (ANN)***

# %%
df6
# Out:
#        HV024  HV025  HV270  HV104  ...  SB333AA  SB333AB    SBBM  Deabetic
# 0          1      2      3      2  ...    125.0     76.0  2119.0         0
# 1          1      2      2      1  ...    122.0     82.0  2068.0         1
# 2          1      2      1      2  ...    129.0     65.0  1716.0         0
# 3          1      2      4      1  ...    130.0     88.0  1858.0         0
# 4          1      2      4      2  ...    190.0     96.0  1539.0         1
# ...      ...    ...    ...    ...  ...      ...      ...     ...       ...
# 16766      8      1      5      2  ...    129.0     96.0  2682.0         1
# 16767      8      1      5      2  ...    110.0     79.0  2389.0         1
# 16768      8      1      5      1  ...    114.0     69.0  2154.0         1
# 16769      8      1      5      2  ...    130.0     79.0  2761.0         0
# 16770      8      1      5      2  ...    142.0     71.0  1597.0         1
#
# [16771 rows x 14 columns]

# %%
X = df6.copy()  #independent columns
y = X.pop('Deabetic')    #target column i.e price range

# %%
X
# Out:
#        HV024  HV025  HV270  HV104  ...  SB311C  SB333AA  SB333AB    SBBM
# 0          1      2      3      2  ...     0.0    125.0     76.0  2119.0
# 1          1      2      2      1  ...     0.0    122.0     82.0  2068.0
# 2          1      2      1      2  ...     0.0    129.0     65.0  1716.0
# 3          1      2      4      1  ...     0.0    130.0     88.0  1858.0
# 4          1      2      4      2  ...     0.0    190.0     96.0  1539.0
# ...      ...    ...    ...    ...  ...     ...      ...      ...     ...
# 16766      8      1      5      2  ...     1.0    129.0     96.0  2682.0
# 16767      8      1      5      2  ...     0.0    110.0     79.0  2389.0
# 16768      8      1      5      1  ...     0.0    114.0     69.0  2154.0
# 16769      8      1      5      2  ...     1.0    130.0     79.0  2761.0
# 16770      8      1      5      2  ...     0.0    142.0     71.0  1597.0
#
# [16771 rows x 13 columns]

# %%
y
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 16766    1
# 16767    1
# 16768    1
# 16769    0
# 16770    1
# Name: Deabetic, Length: 16771, dtype: int64

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train, X_test
# Out:
# (array([[ 1.21522903, -1.37890684,  1.36454092, ...,  0.11515496,
#           0.72781629, -0.15888168],
#         [-1.55897124,  0.72521215, -1.44151073, ..., -0.74368299,
#          -0.56310515, -0.35358596],
#         [-1.09660453, -1.37890684,  1.36454092, ..., -0.10888972,
#          -0.18060991,  1.6822191 ],
#         ...,
#         [-0.17187111,  0.72521215, -0.03848491, ..., -0.1462305 ,
#          -0.0849861 ,  0.48822373],
#         [-0.17187111, -1.37890684, -1.44151073, ...,  0.52590355,
#          -0.0849861 ,  0.59130246],
#         [-0.17187111, -1.37890684,  1.36454092, ...,  0.67526667,
#           1.15812343, -1.18107916]]),
#  array([[-0.63423782,  0.72521215,  1.36454092, ..., -0.81836455,
#          -0.9456004 , -0.54256365],
#         [-1.55897124,  0.72521215, -1.44151073, ...,  0.37654043,
#           0.20188533, -1.40155313],
#         [-0.17187111,  0.72521215, -1.44151073, ..., -0.1462305 ,
#          -0.18060991, -1.30992758],
#         ...,
#         [ 1.21522903,  0.72521215,  0.66302801, ...,  1.64612697,
#           1.15812343,  2.00004521],
#         [-0.63423782,  0.72521215, -0.03848491, ...,  0.11515496,
#           0.05844961, -0.96919509],
#         [-1.09660453,  0.72521215,  0.66302801, ..., -1.15443158,
#          -0.84997659, -0.48816098]]))

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu', input_dim = 13))
# classifier.add(Dropout(p = 0.1))

# Adding the second hidden layer
classifier.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu'))
# classifier.add(Dropout(p = 0.1))

# Adding the second hidden layer
classifier.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu'))
# classifier.add(Dropout(p = 0.1))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 1342/1342 [==============================] - 7s 3ms/step - loss: 0.6848 - accuracy: 0.5458
# Epoch 2/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6605 - accuracy: 0.6066
# Epoch 3/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6623 - accuracy: 0.6080
# Epoch 4/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6635 - accuracy: 0.5989
# Epoch 5/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6608 - accuracy: 0.6044
# Epoch 6/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6611 - accuracy: 0.6086
# Epoch 7/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6589 - accuracy: 0.6070
# Epoch 8/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6586 - accuracy: 0.6081
# Epoch 9/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6623 - accuracy: 0.6017
# Epoch 10/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6547 - accuracy: 0.6144
# Epoch 11/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6620 - accuracy: 0.5952
# Epoch 12/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6546 - accuracy: 0.6189
# Epoch 13/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6617 - accuracy: 0.6057
# Epoch 14/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6574 - accuracy: 0.6093
# Epoch 15/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6552 - accuracy: 0.6152
# Epoch 16/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6571 - accuracy: 0.6123
# Epoch 17/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6583 - accuracy: 0.6103
# Epoch 18/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6552 - accuracy: 0.6164
# Epoch 19/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6562 - accuracy: 0.6114
# Epoch 20/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6559 - accuracy: 0.6176
# Epoch 21/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6583 - accuracy: 0.6130
# Epoch 22/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6509 - accuracy: 0.6196
# Epoch 23/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6532 - accuracy: 0.6141
# Epoch 24/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6541 - accuracy: 0.6133
# Epoch 25/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6557 - accuracy: 0.6095
# Epoch 26/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6589 - accuracy: 0.6103
# Epoch 27/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6580 - accuracy: 0.6131
# Epoch 28/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6576 - accuracy: 0.6136
# Epoch 29/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6554 - accuracy: 0.6124
# Epoch 30/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6515 - accuracy: 0.6221
# Epoch 31/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6560 - accuracy: 0.6147
# Epoch 32/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6576 - accuracy: 0.6173
# Epoch 33/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6530 - accuracy: 0.6174
# Epoch 34/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6478 - accuracy: 0.6243
# Epoch 35/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6540 - accuracy: 0.6230
# Epoch 36/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6569 - accuracy: 0.6114
# Epoch 37/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6531 - accuracy: 0.6226
# Epoch 38/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6488 - accuracy: 0.6176
# Epoch 39/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6580 - accuracy: 0.6105
# Epoch 40/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6530 - accuracy: 0.6162
# Epoch 41/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6564 - accuracy: 0.6146
# Epoch 42/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6183
# Epoch 43/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6224
# Epoch 44/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6553 - accuracy: 0.6151
# Epoch 45/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6584 - accuracy: 0.6105
# Epoch 46/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6536 - accuracy: 0.6195
# Epoch 47/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6221
# Epoch 48/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6486 - accuracy: 0.6306
# Epoch 49/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6527 - accuracy: 0.6205
# Epoch 50/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6507 - accuracy: 0.6249
# Epoch 51/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6508 - accuracy: 0.6234
# Epoch 52/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6580 - accuracy: 0.6174
# Epoch 53/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6563 - accuracy: 0.6119
# Epoch 54/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6525 - accuracy: 0.6205
# Epoch 55/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6513 - accuracy: 0.6197
# Epoch 56/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6185
# Epoch 57/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6519 - accuracy: 0.6277
# Epoch 58/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6152
# Epoch 59/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6550 - accuracy: 0.6189
# Epoch 60/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6519 - accuracy: 0.6238
# Epoch 61/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6525 - accuracy: 0.6156
# Epoch 62/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6493 - accuracy: 0.6241
# Epoch 63/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6526 - accuracy: 0.6210
# Epoch 64/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6534 - accuracy: 0.6212
# Epoch 65/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6571 - accuracy: 0.6089
# Epoch 66/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6556 - accuracy: 0.6162
# Epoch 67/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6534 - accuracy: 0.6209
# Epoch 68/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6528 - accuracy: 0.6173
# Epoch 69/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6518 - accuracy: 0.6153
# Epoch 70/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6463 - accuracy: 0.6343
# Epoch 71/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6244
# Epoch 72/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6541 - accuracy: 0.6179
# Epoch 73/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6515 - accuracy: 0.6242
# Epoch 74/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6498 - accuracy: 0.6261
# Epoch 75/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6524 - accuracy: 0.6249
# Epoch 76/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6544 - accuracy: 0.6193
# Epoch 77/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6497 - accuracy: 0.6243
# Epoch 78/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6492 - accuracy: 0.6305
# Epoch 79/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6481 - accuracy: 0.6253
# Epoch 80/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6481 - accuracy: 0.6245
# Epoch 81/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6505 - accuracy: 0.6257
# Epoch 82/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6557 - accuracy: 0.6172
# Epoch 83/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6490 - accuracy: 0.6268
# Epoch 84/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6498 - accuracy: 0.6269
# Epoch 85/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6556 - accuracy: 0.6209
# Epoch 86/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6547 - accuracy: 0.6217
# Epoch 87/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6553 - accuracy: 0.6189
# Epoch 88/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6586 - accuracy: 0.6057
# Epoch 89/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6519 - accuracy: 0.6248
# Epoch 90/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6529 - accuracy: 0.6204
# Epoch 91/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6542 - accuracy: 0.6192
# Epoch 92/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6474 - accuracy: 0.6314
# Epoch 93/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6547 - accuracy: 0.6165
# Epoch 94/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6205
# Epoch 95/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6493 - accuracy: 0.6289
# Epoch 96/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6248
# Epoch 97/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6546 - accuracy: 0.6224
# Epoch 98/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6572 - accuracy: 0.6149
# Epoch 99/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6531 - accuracy: 0.6208
# Epoch 100/100
# 1342/1342 [==============================] - 4s 3ms/step - loss: 0.6557 - accuracy: 0.6201

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1221,  529],
#        [ 746,  859]])

# %%
accuracy = (cm[0][0] + cm[1][1]) / (cm[0][0] + cm[0][1] + cm[1][0] + cm[1][1])
accuracy
# Out:
# 0.6199701937406855

# %% [markdown]
# #**Evaluating, Improving and Tuning the ANN**

# %% [markdown]
# ###**Evaluting ANN**

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense

# %%
def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu', input_dim = 13))
    classifier.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier, batch_size = 10, epochs = 100)
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
# Out:
# Epoch 1/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6896 - accuracy: 0.5367
# Epoch 2/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6639 - accuracy: 0.6028
# Epoch 3/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6630 - accuracy: 0.5996
# Epoch 4/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6635 - accuracy: 0.5993
# Epoch 5/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6615 - accuracy: 0.6041
# Epoch 6/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6538 - accuracy: 0.6198
# Epoch 7/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6622 - accuracy: 0.6030
# Epoch 8/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6592 - accuracy: 0.6088
# Epoch 9/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6575 - accuracy: 0.6057
# Epoch 10/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6585 - accuracy: 0.6113
# Epoch 11/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6566 - accuracy: 0.6043
# Epoch 12/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6516 - accuracy: 0.6201
# Epoch 13/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6582 - accuracy: 0.6028
# Epoch 14/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6553 - accuracy: 0.6117
# Epoch 15/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6557 - accuracy: 0.6115
# Epoch 16/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6506 - accuracy: 0.6189
# Epoch 17/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6581 - accuracy: 0.6138
# Epoch 18/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6568 - accuracy: 0.6098
# Epoch 19/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6535 - accuracy: 0.6154
# Epoch 20/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6541 - accuracy: 0.6123
# Epoch 21/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6591 - accuracy: 0.6134
# Epoch 22/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6546 - accuracy: 0.6162
# Epoch 23/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6609 - accuracy: 0.6034
# Epoch 24/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6559 - accuracy: 0.6072
# Epoch 25/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6576 - accuracy: 0.6009
# Epoch 26/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6563 - accuracy: 0.6150
# Epoch 27/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6531 - accuracy: 0.6177
# Epoch 28/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6491 - accuracy: 0.6197
# Epoch 29/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6556 - accuracy: 0.6128
# Epoch 30/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6545 - accuracy: 0.6133
# Epoch 31/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6525 - accuracy: 0.6160
# Epoch 32/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6597 - accuracy: 0.6080
# Epoch 33/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6551 - accuracy: 0.6174
# Epoch 34/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6532 - accuracy: 0.6148
# Epoch 35/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6559 - accuracy: 0.6157
# Epoch 36/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6567 - accuracy: 0.6142
# Epoch 37/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6521 - accuracy: 0.6222
# Epoch 38/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6554 - accuracy: 0.6160
# Epoch 39/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6514 - accuracy: 0.6188
# Epoch 40/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6551 - accuracy: 0.6146
# Epoch 41/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6233
# Epoch 42/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6183
# Epoch 43/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6563 - accuracy: 0.6169
# Epoch 44/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6517 - accuracy: 0.6234
# Epoch 45/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6534 - accuracy: 0.6188
# Epoch 46/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6542 - accuracy: 0.6175
# Epoch 47/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6517 - accuracy: 0.6215
# Epoch 48/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6497 - accuracy: 0.6265
# Epoch 49/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6517 - accuracy: 0.6219
# Epoch 50/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6556 - accuracy: 0.6173
# Epoch 51/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6511 - accuracy: 0.6232
# Epoch 52/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6529 - accuracy: 0.6197
# Epoch 53/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6505 - accuracy: 0.6268
# Epoch 54/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6560 - accuracy: 0.6150
# Epoch 55/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6501 - accuracy: 0.6236
# Epoch 56/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6526 - accuracy: 0.6206
# Epoch 57/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6555 - accuracy: 0.6156
# Epoch 58/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6527 - accuracy: 0.6209
# Epoch 59/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6537 - accuracy: 0.6175
# Epoch 60/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6534 - accuracy: 0.6236
# Epoch 61/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6174
# Epoch 62/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6546 - accuracy: 0.6199
# Epoch 63/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6490 - accuracy: 0.6253
# Epoch 64/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6537 - accuracy: 0.6194
# Epoch 65/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6558 - accuracy: 0.6173
# Epoch 66/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6519 - accuracy: 0.6209
# Epoch 67/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6200
# Epoch 68/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6555 - accuracy: 0.6195
# Epoch 69/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6526 - accuracy: 0.6184
# Epoch 70/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6549 - accuracy: 0.6190
# Epoch 71/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6519 - accuracy: 0.6266
# Epoch 72/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6491 - accuracy: 0.6289
# Epoch 73/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6515 - accuracy: 0.6193
# Epoch 74/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6497 - accuracy: 0.6297
# Epoch 75/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6501 - accuracy: 0.6239
# Epoch 76/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6504 - accuracy: 0.6239
# Epoch 77/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6509 - accuracy: 0.6225
# Epoch 78/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6451 - accuracy: 0.6328
# Epoch 79/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6501 - accuracy: 0.6227
# Epoch 80/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6563 - accuracy: 0.6190
# Epoch 81/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6513 - accuracy: 0.6260
# Epoch 82/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6520 - accuracy: 0.6209
# Epoch 83/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6489 - accuracy: 0.6295
# Epoch 84/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6504 - accuracy: 0.6218
# Epoch 85/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6452 - accuracy: 0.6342
# Epoch 86/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6478 - accuracy: 0.6260
# Epoch 87/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6537 - accuracy: 0.6216
# Epoch 88/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6487 - accuracy: 0.6289
# Epoch 89/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6518 - accuracy: 0.6258
# Epoch 90/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6525 - accuracy: 0.6257
# Epoch 91/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6482 - accuracy: 0.6295
# Epoch 92/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6522 - accuracy: 0.6232
# Epoch 93/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6506 - accuracy: 0.6268
# Epoch 94/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6503 - accuracy: 0.6307
# Epoch 95/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6505 - accuracy: 0.6297
# Epoch 96/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6475 - accuracy: 0.6320
# Epoch 97/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6493 - accuracy: 0.6306
# Epoch 98/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6529 - accuracy: 0.6183
# Epoch 99/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6537 - accuracy: 0.6196
# Epoch 100/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6517 - accuracy: 0.6194
# 135/135 [==============================] - 0s 2ms/step - loss: 0.6673 - accuracy: 0.6058
# Epoch 1/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5063
# Epoch 2/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6923 - accuracy: 0.5214
# Epoch 3/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5157
# Epoch 4/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5191
# Epoch 5/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5141
# Epoch 6/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6924 - accuracy: 0.5197
# Epoch 7/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5148
# Epoch 8/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6921 - accuracy: 0.5239
# Epoch 9/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5166
# Epoch 10/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6930 - accuracy: 0.5110
# Epoch 11/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6930 - accuracy: 0.5114
# Epoch 12/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5141
# Epoch 13/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5190
# Epoch 14/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5127
# Epoch 15/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5129
# Epoch 16/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5152
# Epoch 17/100
# 1208/1208 [==============================] - 3s 3ms/step - loss: 0.6928 - accuracy: 0.5134
# Epoch 18/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5163
# Epoch 19/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6924 - accuracy: 0.5199
# Epoch 20/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6933 - accuracy: 0.5046
# Epoch 21/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5188
# Epoch 22/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6924 - accuracy: 0.5205
# Epoch 23/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5182
# Epoch 24/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5137
# Epoch 25/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6926 - accuracy: 0.5172
# Epoch 26/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6926 - accuracy: 0.5186
# Epoch 27/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5191
# Epoch 28/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5118
# Epoch 29/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5187
# Epoch 30/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5191
# Epoch 31/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6924 - accuracy: 0.5215
# Epoch 32/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5066
# Epoch 33/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5117
# Epoch 34/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6926 - accuracy: 0.5174
# Epoch 35/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6922 - accuracy: 0.5222
# Epoch 36/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5141
# Epoch 37/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5161
# Epoch 38/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6921 - accuracy: 0.5253
# Epoch 39/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5173
# Epoch 40/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5153
# Epoch 41/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6926 - accuracy: 0.5179
# Epoch 42/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6926 - accuracy: 0.5181
# Epoch 43/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5133
# Epoch 44/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6924 - accuracy: 0.5196
# Epoch 45/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5158
# Epoch 46/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5127
# Epoch 47/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6933 - accuracy: 0.5045
# Epoch 48/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6933 - accuracy: 0.5083
# Epoch 49/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5161
# Epoch 50/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5190
# Epoch 51/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5165
# Epoch 52/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6921 - accuracy: 0.5239
# Epoch 53/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5168
# Epoch 54/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5140
# Epoch 55/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6921 - accuracy: 0.5238
# Epoch 56/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5137
# Epoch 57/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6924 - accuracy: 0.5199
# Epoch 58/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6924 - accuracy: 0.5208
# Epoch 59/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5141
# Epoch 60/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6924 - accuracy: 0.5198
# Epoch 61/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5164
# Epoch 62/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5089
# Epoch 63/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5186
# Epoch 64/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5183
# Epoch 65/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6922 - accuracy: 0.5244
# Epoch 66/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5156
# Epoch 67/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6926 - accuracy: 0.5176
# Epoch 68/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5193
# Epoch 69/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6933 - accuracy: 0.5043
# Epoch 70/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6920 - accuracy: 0.5241
# Epoch 71/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6930 - accuracy: 0.5106
# Epoch 72/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5138
# Epoch 73/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6933 - accuracy: 0.5058
# Epoch 74/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5122
# Epoch 75/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5148
# Epoch 76/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5130
# Epoch 77/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5186
# Epoch 78/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6923 - accuracy: 0.5231
# Epoch 79/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5134
# Epoch 80/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5157
# Epoch 81/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6924 - accuracy: 0.5197
# Epoch 82/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5134
# Epoch 83/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5162
# Epoch 84/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5200
# Epoch 85/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5138
# Epoch 86/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6926 - accuracy: 0.5171
# Epoch 87/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5133
# Epoch 88/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5154
# Epoch 89/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6930 - accuracy: 0.5113
# Epoch 90/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5159
# Epoch 91/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5121
# Epoch 92/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6923 - accuracy: 0.5217
# Epoch 93/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6930 - accuracy: 0.5098
# Epoch 94/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6925 - accuracy: 0.5182
# Epoch 95/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6926 - accuracy: 0.5179
# Epoch 96/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5057
# Epoch 97/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6929 - accuracy: 0.5125
# Epoch 98/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6928 - accuracy: 0.5142
# Epoch 99/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6930 - accuracy: 0.5113
# Epoch 100/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6927 - accuracy: 0.5159
# 135/135 [==============================] - 0s 2ms/step - loss: 0.6926 - accuracy: 0.5171
# Epoch 1/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6875 - accuracy: 0.5362
# Epoch 2/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6603 - accuracy: 0.6124
# Epoch 3/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6597 - accuracy: 0.6111
# Epoch 4/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6575 - accuracy: 0.6103
# Epoch 5/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6600 - accuracy: 0.6065
# Epoch 6/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6561 - accuracy: 0.6133
# Epoch 7/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6589 - accuracy: 0.6056
# Epoch 8/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6544 - accuracy: 0.6192
# Epoch 9/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6547 - accuracy: 0.6129
# Epoch 10/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6518 - accuracy: 0.6207
# Epoch 11/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6546 - accuracy: 0.6106
# Epoch 12/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6564 - accuracy: 0.6135
# Epoch 13/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6569 - accuracy: 0.6125
# Epoch 14/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6582 - accuracy: 0.6118
# Epoch 15/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6578 - accuracy: 0.6124
# Epoch 16/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6469 - accuracy: 0.6293
# Epoch 17/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6531 - accuracy: 0.6177
# Epoch 18/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6540 - accuracy: 0.6179
# Epoch 19/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6494 - accuracy: 0.6287
# Epoch 20/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6513 - accuracy: 0.6234
# Epoch 21/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6241
# Epoch 22/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6532 - accuracy: 0.6195
# Epoch 23/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6466 - accuracy: 0.6305
# Epoch 24/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6530 - accuracy: 0.6194
# Epoch 25/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6529 - accuracy: 0.6181
# Epoch 26/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6494 - accuracy: 0.6254
# Epoch 27/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6536 - accuracy: 0.6209
# Epoch 28/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6532 - accuracy: 0.6192
# Epoch 29/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6506 - accuracy: 0.6251
# Epoch 30/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6550 - accuracy: 0.6187
# Epoch 31/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6509 - accuracy: 0.6196
# Epoch 32/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6187
# Epoch 33/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6523 - accuracy: 0.6220
# Epoch 34/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6484 - accuracy: 0.6245
# Epoch 35/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6534 - accuracy: 0.6166
# Epoch 36/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6481 - accuracy: 0.6248
# Epoch 37/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6458 - accuracy: 0.6293
# Epoch 38/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6483 - accuracy: 0.6282
# Epoch 39/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6520 - accuracy: 0.6164
# Epoch 40/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6505 - accuracy: 0.6298
# Epoch 41/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6496 - accuracy: 0.6263
# Epoch 42/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6464 - accuracy: 0.6286
# Epoch 43/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6528 - accuracy: 0.6179
# Epoch 44/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6484 - accuracy: 0.6293
# Epoch 45/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6554 - accuracy: 0.6135
# Epoch 46/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6468 - accuracy: 0.6315
# Epoch 47/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6484 - accuracy: 0.6244
# Epoch 48/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6450 - accuracy: 0.6346
# Epoch 49/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6495 - accuracy: 0.6245
# Epoch 50/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6503 - accuracy: 0.6259
# Epoch 51/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6533 - accuracy: 0.6182
# Epoch 52/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6493 - accuracy: 0.6268
# Epoch 53/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6490 - accuracy: 0.6251
# Epoch 54/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6496 - accuracy: 0.6285
# Epoch 55/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6466 - accuracy: 0.6295
# Epoch 56/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6238
# Epoch 57/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6502 - accuracy: 0.6288
# Epoch 58/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6487 - accuracy: 0.6278
# Epoch 59/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6492 - accuracy: 0.6279
# Epoch 60/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6227
# Epoch 61/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6498 - accuracy: 0.6294
# Epoch 62/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6541 - accuracy: 0.6163
# Epoch 63/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6518 - accuracy: 0.6291
# Epoch 64/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6529 - accuracy: 0.6171
# Epoch 65/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6484 - accuracy: 0.6274
# Epoch 66/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6470 - accuracy: 0.6315
# Epoch 67/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6202
# Epoch 68/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6486 - accuracy: 0.6288
# Epoch 69/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6487 - accuracy: 0.6263
# Epoch 70/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6539 - accuracy: 0.6188
# Epoch 71/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6569 - accuracy: 0.6176
# Epoch 72/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6517 - accuracy: 0.6234
# Epoch 73/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6532 - accuracy: 0.6238
# Epoch 74/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6524 - accuracy: 0.6225
# Epoch 75/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6489 - accuracy: 0.6276
# Epoch 76/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6510 - accuracy: 0.6193
# Epoch 77/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6464 - accuracy: 0.6358
# Epoch 78/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6489 - accuracy: 0.6251
# Epoch 79/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6505 - accuracy: 0.6263
# Epoch 80/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6546 - accuracy: 0.6224
# Epoch 81/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6468 - accuracy: 0.6318
# Epoch 82/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6498 - accuracy: 0.6269
# Epoch 83/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6477 - accuracy: 0.6281
# Epoch 84/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6549 - accuracy: 0.6142
# Epoch 85/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6475 - accuracy: 0.6301
# Epoch 86/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6488 - accuracy: 0.6304
# Epoch 87/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6523 - accuracy: 0.6287
# Epoch 88/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6512 - accuracy: 0.6267
# Epoch 89/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6507 - accuracy: 0.6221
# Epoch 90/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6493 - accuracy: 0.6244
# Epoch 91/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6510 - accuracy: 0.6249
# Epoch 92/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6490 - accuracy: 0.6310
# Epoch 93/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6509 - accuracy: 0.6292
# Epoch 94/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6423 - accuracy: 0.6389
# Epoch 95/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6490 - accuracy: 0.6302
# Epoch 96/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6487 - accuracy: 0.6305
# Epoch 97/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6509 - accuracy: 0.6269
# Epoch 98/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6480 - accuracy: 0.6317
# Epoch 99/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6529 - accuracy: 0.6204
# Epoch 100/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6510 - accuracy: 0.6264
# 135/135 [==============================] - 0s 2ms/step - loss: 0.6755 - accuracy: 0.5902
# Epoch 1/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6852 - accuracy: 0.5544
# Epoch 2/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6675 - accuracy: 0.5978
# Epoch 3/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6640 - accuracy: 0.6035
# Epoch 4/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6632 - accuracy: 0.6037
# Epoch 5/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6616 - accuracy: 0.6068
# Epoch 6/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6574 - accuracy: 0.6118
# Epoch 7/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6592 - accuracy: 0.6104
# Epoch 8/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6591 - accuracy: 0.6075
# Epoch 9/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6585 - accuracy: 0.6066
# Epoch 10/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6597 - accuracy: 0.6063
# Epoch 11/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6144
# Epoch 12/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6623 - accuracy: 0.6016
# Epoch 13/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6567 - accuracy: 0.6090
# Epoch 14/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6603 - accuracy: 0.6039
# Epoch 15/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6577 - accuracy: 0.6110
# Epoch 16/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6561 - accuracy: 0.6156
# Epoch 17/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6517 - accuracy: 0.6208
# Epoch 18/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6545 - accuracy: 0.6160
# Epoch 19/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6519 - accuracy: 0.6184
# Epoch 20/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6564 - accuracy: 0.6150
# Epoch 21/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6556 - accuracy: 0.6161
# Epoch 22/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6560 - accuracy: 0.6168
# Epoch 23/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6577 - accuracy: 0.6178
# Epoch 24/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6532 - accuracy: 0.6201
# Epoch 25/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6558 - accuracy: 0.6158
# Epoch 26/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6581 - accuracy: 0.6021
# Epoch 27/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6539 - accuracy: 0.6146
# Epoch 28/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6531 - accuracy: 0.6137
# Epoch 29/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6554 - accuracy: 0.6160
# Epoch 30/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6568 - accuracy: 0.6172
# Epoch 31/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6531 - accuracy: 0.6172
# Epoch 32/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6526 - accuracy: 0.6201
# Epoch 33/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6199
# Epoch 34/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6527 - accuracy: 0.6177
# Epoch 35/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6548 - accuracy: 0.6140
# Epoch 36/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6525 - accuracy: 0.6189
# Epoch 37/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6545 - accuracy: 0.6214
# Epoch 38/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6528 - accuracy: 0.6146
# Epoch 39/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6565 - accuracy: 0.6226
# Epoch 40/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6526 - accuracy: 0.6205
# Epoch 41/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6525 - accuracy: 0.6195
# Epoch 42/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6542 - accuracy: 0.6138
# Epoch 43/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6486 - accuracy: 0.6226
# Epoch 44/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6540 - accuracy: 0.6146
# Epoch 45/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6522 - accuracy: 0.6184
# Epoch 46/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6558 - accuracy: 0.6142
# Epoch 47/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6516 - accuracy: 0.6210
# Epoch 48/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6473 - accuracy: 0.6282
# Epoch 49/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6528 - accuracy: 0.6183
# Epoch 50/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6542 - accuracy: 0.6170
# Epoch 51/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6549 - accuracy: 0.6154
# Epoch 52/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6521 - accuracy: 0.6168
# Epoch 53/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6542 - accuracy: 0.6150
# Epoch 54/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6547 - accuracy: 0.6196
# Epoch 55/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6532 - accuracy: 0.6189
# Epoch 56/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6533 - accuracy: 0.6140
# Epoch 57/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6507 - accuracy: 0.6228
# Epoch 58/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6498 - accuracy: 0.6207
# Epoch 59/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6525 - accuracy: 0.6172
# Epoch 60/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6578 - accuracy: 0.6120
# Epoch 61/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6581 - accuracy: 0.6103
# Epoch 62/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6495 - accuracy: 0.6142
# Epoch 63/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6573 - accuracy: 0.6095
# Epoch 64/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6559 - accuracy: 0.6122
# Epoch 65/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6520 - accuracy: 0.6191
# Epoch 66/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6498 - accuracy: 0.6174
# Epoch 67/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6509 - accuracy: 0.6188
# Epoch 68/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6538 - accuracy: 0.6165
# Epoch 69/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6559 - accuracy: 0.6152
# Epoch 70/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6495 - accuracy: 0.6175
# Epoch 71/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6504 - accuracy: 0.6203
# Epoch 72/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6546 - accuracy: 0.6167
# Epoch 73/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6524 - accuracy: 0.6173
# Epoch 74/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6586 - accuracy: 0.6102
# Epoch 75/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6562 - accuracy: 0.6145
# Epoch 76/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6501 - accuracy: 0.6238
# Epoch 77/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6526 - accuracy: 0.6202
# Epoch 78/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6520 - accuracy: 0.6176
# Epoch 79/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6571 - accuracy: 0.6125
# Epoch 80/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6555 - accuracy: 0.6102
# Epoch 81/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6520 - accuracy: 0.6189
# Epoch 82/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6509 - accuracy: 0.6218
# Epoch 83/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6513 - accuracy: 0.6222
# Epoch 84/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6086
# Epoch 85/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6121
# Epoch 86/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6542 - accuracy: 0.6143
# Epoch 87/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6515 - accuracy: 0.6194
# Epoch 88/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6482 - accuracy: 0.6244
# Epoch 89/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6505 - accuracy: 0.6213
# Epoch 90/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6525 - accuracy: 0.6215
# Epoch 91/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6541 - accuracy: 0.6146
# Epoch 92/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6516 - accuracy: 0.6192
# Epoch 93/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6552 - accuracy: 0.6131
# Epoch 94/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6517 - accuracy: 0.6188
# Epoch 95/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6537 - accuracy: 0.6189
# Epoch 96/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6495 - accuracy: 0.6212
# Epoch 97/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6493 - accuracy: 0.6199
# Epoch 98/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6512 - accuracy: 0.6235
# Epoch 99/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6517 - accuracy: 0.6182
# Epoch 100/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6515 - accuracy: 0.6195
# 135/135 [==============================] - 0s 2ms/step - loss: 0.6688 - accuracy: 0.6028
# Epoch 1/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6870 - accuracy: 0.5362
# Epoch 2/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6698 - accuracy: 0.5970
# Epoch 3/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6670 - accuracy: 0.5973
# Epoch 4/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6655 - accuracy: 0.6043
# Epoch 5/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6618 - accuracy: 0.6078
# Epoch 6/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6592 - accuracy: 0.6149
# Epoch 7/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6651 - accuracy: 0.6016
# Epoch 8/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6636 - accuracy: 0.6004
# Epoch 9/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6593 - accuracy: 0.6120
# Epoch 10/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6594 - accuracy: 0.6067
# Epoch 11/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6589 - accuracy: 0.6069
# Epoch 12/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6568 - accuracy: 0.6108
# Epoch 13/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6605 - accuracy: 0.6118
# Epoch 14/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6598 - accuracy: 0.6064
# Epoch 15/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6574 - accuracy: 0.6144
# Epoch 16/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6576 - accuracy: 0.6098
# Epoch 17/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6569 - accuracy: 0.6101
# Epoch 18/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6554 - accuracy: 0.6149
# Epoch 19/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6585 - accuracy: 0.6123
# Epoch 20/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6577 - accuracy: 0.6166
# Epoch 21/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6554 - accuracy: 0.6214
# Epoch 22/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6571 - accuracy: 0.6059
# Epoch 23/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6539 - accuracy: 0.6177
# Epoch 24/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6595 - accuracy: 0.6072
# Epoch 25/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6582 - accuracy: 0.6158
# Epoch 26/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6558 - accuracy: 0.6192
# Epoch 27/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6181
# Epoch 28/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6571 - accuracy: 0.6118
# Epoch 29/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6121
# Epoch 30/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6539 - accuracy: 0.6153
# Epoch 31/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6564 - accuracy: 0.6112
# Epoch 32/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6575 - accuracy: 0.6112
# Epoch 33/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6581 - accuracy: 0.6125
# Epoch 34/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6552 - accuracy: 0.6130
# Epoch 35/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6522 - accuracy: 0.6175
# Epoch 36/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6576 - accuracy: 0.6107
# Epoch 37/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6569 - accuracy: 0.6124
# Epoch 38/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6548 - accuracy: 0.6131
# Epoch 39/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6614 - accuracy: 0.6048
# Epoch 40/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6562 - accuracy: 0.6161
# Epoch 41/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6545 - accuracy: 0.6138
# Epoch 42/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6540 - accuracy: 0.6207
# Epoch 43/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6582 - accuracy: 0.6080
# Epoch 44/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6546 - accuracy: 0.6130
# Epoch 45/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6539 - accuracy: 0.6152
# Epoch 46/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6569 - accuracy: 0.6134
# Epoch 47/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6544 - accuracy: 0.6151
# Epoch 48/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6582 - accuracy: 0.6074
# Epoch 49/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6502 - accuracy: 0.6155
# Epoch 50/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6164
# Epoch 51/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6550 - accuracy: 0.6154
# Epoch 52/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6519 - accuracy: 0.6171
# Epoch 53/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6511 - accuracy: 0.6215
# Epoch 54/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6530 - accuracy: 0.6151
# Epoch 55/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6568 - accuracy: 0.6116
# Epoch 56/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6563 - accuracy: 0.6118
# Epoch 57/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6498 - accuracy: 0.6239
# Epoch 58/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6526 - accuracy: 0.6152
# Epoch 59/100
# ...
# Epoch 49/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6607 - accuracy: 0.6013
# Epoch 50/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6617 - accuracy: 0.6053
# Epoch 51/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6621 - accuracy: 0.6053
# Epoch 52/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6586 - accuracy: 0.6054
# Epoch 53/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6602 - accuracy: 0.6063
# Epoch 54/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6599 - accuracy: 0.6082
# Epoch 55/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6574 - accuracy: 0.6117
# Epoch 56/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6591 - accuracy: 0.6043
# Epoch 57/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6601 - accuracy: 0.6155
# Epoch 58/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6586 - accuracy: 0.6063
# Epoch 59/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6595 - accuracy: 0.6055
# Epoch 60/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6543 - accuracy: 0.6156
# Epoch 61/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6588 - accuracy: 0.6099
# Epoch 62/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6567 - accuracy: 0.6154
# Epoch 63/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6557 - accuracy: 0.6127
# Epoch 64/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6629 - accuracy: 0.6016
# Epoch 65/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6581 - accuracy: 0.6082
# Epoch 66/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6563 - accuracy: 0.6055
# Epoch 67/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6611 - accuracy: 0.6023
# Epoch 68/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6552 - accuracy: 0.6151
# Epoch 69/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6524 - accuracy: 0.6133
# Epoch 70/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6575 - accuracy: 0.6045
# Epoch 71/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6541 - accuracy: 0.6136
# Epoch 72/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6550 - accuracy: 0.6142
# Epoch 73/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6592 - accuracy: 0.6038
# Epoch 74/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6561 - accuracy: 0.6151
# Epoch 75/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6542 - accuracy: 0.6177
# Epoch 76/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6528 - accuracy: 0.6174
# Epoch 77/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6609 - accuracy: 0.6019
# Epoch 78/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6530 - accuracy: 0.6105
# Epoch 79/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6604 - accuracy: 0.6096
# Epoch 80/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6544 - accuracy: 0.6118
# Epoch 81/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6595 - accuracy: 0.6096
# Epoch 82/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6576 - accuracy: 0.6101
# Epoch 83/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6566 - accuracy: 0.6141
# Epoch 84/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6532 - accuracy: 0.6139
# Epoch 85/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6583 - accuracy: 0.6058
# Epoch 86/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6537 - accuracy: 0.6152
# Epoch 87/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6568 - accuracy: 0.6112
# Epoch 88/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6513 - accuracy: 0.6222
# Epoch 89/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6585 - accuracy: 0.6087
# Epoch 90/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6569 - accuracy: 0.6164
# Epoch 91/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6533 - accuracy: 0.6156
# Epoch 92/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6573 - accuracy: 0.6094
# Epoch 93/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6599 - accuracy: 0.6047
# Epoch 94/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6564 - accuracy: 0.6087
# Epoch 95/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6536 - accuracy: 0.6187
# Epoch 96/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6559 - accuracy: 0.6094
# Epoch 97/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6573 - accuracy: 0.6083
# Epoch 98/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6584 - accuracy: 0.6099
# Epoch 99/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6590 - accuracy: 0.6057
# Epoch 100/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6565 - accuracy: 0.6149
# 135/135 [==============================] - 0s 2ms/step - loss: 0.6643 - accuracy: 0.6003
# Epoch 1/100
# 1208/1208 [==============================] - 5s 3ms/step - loss: 0.6889 - accuracy: 0.5282
# Epoch 2/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6698 - accuracy: 0.6043
# Epoch 3/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6671 - accuracy: 0.5992
# Epoch 4/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6686 - accuracy: 0.6015
# Epoch 5/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6616 - accuracy: 0.6154
# Epoch 6/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6637 - accuracy: 0.6043
# Epoch 7/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6628 - accuracy: 0.6083
# Epoch 8/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6623 - accuracy: 0.6121
# Epoch 9/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6632 - accuracy: 0.6042
# Epoch 10/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6630 - accuracy: 0.6043
# Epoch 11/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6631 - accuracy: 0.6002
# Epoch 12/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6542 - accuracy: 0.6162
# Epoch 13/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6605 - accuracy: 0.6098
# Epoch 14/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6623 - accuracy: 0.6041
# Epoch 15/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6626 - accuracy: 0.6041
# Epoch 16/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6609 - accuracy: 0.6078
# Epoch 17/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6582 - accuracy: 0.6092
# Epoch 18/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6605 - accuracy: 0.6065
# Epoch 19/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6570 - accuracy: 0.6117
# Epoch 20/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6558 - accuracy: 0.6141
# Epoch 21/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6564 - accuracy: 0.6124
# Epoch 22/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6540 - accuracy: 0.6129
# Epoch 23/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6585 - accuracy: 0.6084
# Epoch 24/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6550 - accuracy: 0.6131
# Epoch 25/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6547 - accuracy: 0.6148
# Epoch 26/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6558 - accuracy: 0.6081
# Epoch 27/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6536 - accuracy: 0.6155
# Epoch 28/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6586 - accuracy: 0.6063
# Epoch 29/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6585 - accuracy: 0.6088
# Epoch 30/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6524 - accuracy: 0.6151
# Epoch 31/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6516 - accuracy: 0.6226
# Epoch 32/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6529 - accuracy: 0.6122
# Epoch 33/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6554 - accuracy: 0.6198
# Epoch 34/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6574 - accuracy: 0.6065
# Epoch 35/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6562 - accuracy: 0.6086
# Epoch 36/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6512 - accuracy: 0.6194
# Epoch 37/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6526 - accuracy: 0.6179
# Epoch 38/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6122
# Epoch 39/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6544 - accuracy: 0.6150
# Epoch 40/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6552 - accuracy: 0.6195
# Epoch 41/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6527 - accuracy: 0.6165
# Epoch 42/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6516 - accuracy: 0.6212
# Epoch 43/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6569 - accuracy: 0.6107
# Epoch 44/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6546 - accuracy: 0.6127
# Epoch 45/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6529 - accuracy: 0.6159
# Epoch 46/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6572 - accuracy: 0.6103
# Epoch 47/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6530 - accuracy: 0.6186
# Epoch 48/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6518 - accuracy: 0.6228
# Epoch 49/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6548 - accuracy: 0.6129
# Epoch 50/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6506 - accuracy: 0.6229
# Epoch 51/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6564 - accuracy: 0.6141
# Epoch 52/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6549 - accuracy: 0.6220
# Epoch 53/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6544 - accuracy: 0.6170
# Epoch 54/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6582 - accuracy: 0.6071
# Epoch 55/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6525 - accuracy: 0.6202
# Epoch 56/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6558 - accuracy: 0.6102
# Epoch 57/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6532 - accuracy: 0.6145
# Epoch 58/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6594 - accuracy: 0.6108
# Epoch 59/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6522 - accuracy: 0.6196
# Epoch 60/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6543 - accuracy: 0.6173
# Epoch 61/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6518 - accuracy: 0.6223
# Epoch 62/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6583 - accuracy: 0.6118
# Epoch 63/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6537 - accuracy: 0.6165
# Epoch 64/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6538 - accuracy: 0.6187
# Epoch 65/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6491 - accuracy: 0.6214
# Epoch 66/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6253
# Epoch 67/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6509 - accuracy: 0.6236
# Epoch 68/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6497 - accuracy: 0.6203
# Epoch 69/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6532 - accuracy: 0.6195
# Epoch 70/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6555 - accuracy: 0.6123
# Epoch 71/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6556 - accuracy: 0.6100
# Epoch 72/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6583 - accuracy: 0.6123
# Epoch 73/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6517 - accuracy: 0.6196
# Epoch 74/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6519 - accuracy: 0.6186
# Epoch 75/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6527 - accuracy: 0.6191
# Epoch 76/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6147
# Epoch 77/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6529 - accuracy: 0.6120
# Epoch 78/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6550 - accuracy: 0.6146
# Epoch 79/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6117
# Epoch 80/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6576 - accuracy: 0.6105
# Epoch 81/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6572 - accuracy: 0.6084
# Epoch 82/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6542 - accuracy: 0.6169
# Epoch 83/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6531 - accuracy: 0.6168
# Epoch 84/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6530 - accuracy: 0.6172
# Epoch 85/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6540 - accuracy: 0.6202
# Epoch 86/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6548 - accuracy: 0.6094
# Epoch 87/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6585 - accuracy: 0.6041
# Epoch 88/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6543 - accuracy: 0.6138
# Epoch 89/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6484 - accuracy: 0.6249
# Epoch 90/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6555 - accuracy: 0.6140
# Epoch 91/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6503 - accuracy: 0.6217
# Epoch 92/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6508 - accuracy: 0.6127
# Epoch 93/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6505 - accuracy: 0.6225
# Epoch 94/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6153
# Epoch 95/100
# 1208/1208 [==============================] - 4s 4ms/step - loss: 0.6499 - accuracy: 0.6205
# Epoch 96/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6522 - accuracy: 0.6179
# Epoch 97/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6587 - accuracy: 0.6076
# Epoch 98/100
# 1208/1208 [==============================] - 4s 3ms/step - loss: 0.6545 - accuracy: 0.6156
# Epoch 99/100
# 1208/1208 [==============================] - 4s 4ms/step - loss: 0.6503 - accuracy: 0.6227
# Epoch 100/100
# 1208/1208 [==============================] - 4s 4ms/step - loss: 0.6509 - accuracy: 0.6217
# 135/135 [==============================] - 0s 2ms/step - loss: 0.6665 - accuracy: 0.5831

# %%
mean = accuracies.mean()
mean
# Out:
# 0.5729721009731292

# %%
variance = accuracies.std()
variance
# Out:
# 0.039026504984569846

# %% [markdown]
# ###**Improving & Tuning the ANN**

# %%
# # Dropout Regularization to reduce overfitting if needed

# # Tuning the ANN
# from keras.wrappers.scikit_learn import KerasClassifier
# from sklearn.model_selection import GridSearchCV
# from keras.models import Sequential
# from keras.layers import Dense

# %%
# def build_classifier(optimizer):
#     classifier = Sequential()
#     classifier.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu', input_dim = 13))
#     classifier.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu'))
#     classifier.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu'))
#     classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
#     classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
#     return classifier

# classifier = KerasClassifier(build_fn = build_classifier)
# parameters = {'batch_size': [10, 25, 32],
#               'epochs': [100, 500],
#               'optimizer': ['adam', 'rmsprop']}
# grid_search = GridSearchCV(estimator = classifier,
#                            param_grid = parameters,
#                            scoring = 'accuracy',
#                            cv = 10)
# grid_search = grid_search.fit(X_train, y_train)

# %%
# best_parameters = grid_search.best_params_
# best_accuracy = grid_search.best_score_

# %%
# best_parameters

# %%
# best_accuracy
